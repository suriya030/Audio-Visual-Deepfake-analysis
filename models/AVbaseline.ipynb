# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset,Subset
from torch.utils.data import random_split
import torch.nn.init as init
import torch.nn.functional as F

import json
import h5py
import os
import numpy as np
import pandas as pd
from tqdm import tqdm
import time
import matplotlib.pyplot as plt
# from adopt import ADOPT
from sklearn.model_selection import train_test_split
import math

from einops import rearrange
from einops.layers.torch import Rearrange
import random

# %%
# (50,1024)
# (2700,13)

# %%
def set_seed(seed):
    os.environ['CUBLAS_WORKSPACE_CONFIG'] = ':4096:8'
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True # only applies to CUDA convolutional operation.
    torch.backends.cudnn.benchmark = False
    np.random.seed(seed)
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    torch.use_deterministic_algorithms(True)

# %%
class TemporalConv1D(nn.Module):
    """Simple temporal conv block for feature alignment"""
    def __init__(self, in_channels, out_channels, kernel_size=3, stride=1, padding=1,dp=0.0):
        super(TemporalConv1D, self).__init__()
        self.conv = nn.Conv1d(in_channels, out_channels, kernel_size=kernel_size, stride=stride,
                               padding=padding)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(dp)
        self.bn = nn.BatchNorm1d(out_channels)

    def forward(self, x):
        x = self.conv(x)
        x = self.relu(x)
        x = self.bn(x)
        return x

# %%
######## cross attention #######

class CrossAttention(nn.Module):
    """Cross-attention between two feature streams"""
    def __init__(self, embed_dim, num_heads=16,dp=0.0):
        super(CrossAttention, self).__init__()
        self.multihead_attn = nn.MultiheadAttention(embed_dim=embed_dim, num_heads=num_heads,
                                                    dropout=dp, batch_first=True)

    def forward(self, query, key, value):
        attn_output, _ = self.multihead_attn(query, key, value)
        return attn_output

# %%
######## MHSA ########
class MHSA(nn.Module):
    """Multi-Head Self Attention"""
    def __init__(self, embed_dim, num_heads=16,dp=0.0):
        super(MHSA, self).__init__()
        self.mhsa = nn.MultiheadAttention(embed_dim=embed_dim, num_heads=num_heads,dropout=dp, 
                                          batch_first=True)

    def forward(self, x):
        attn_output, _ = self.mhsa(x, x, x)
        return attn_output

# %%
######## Fusion model v4 ########

class FusionModel(nn.Module):

    def __init__(self, swin_feat_dim=(50, 1024)):
        
        self.swin_feat_dim = swin_feat_dim
        super(FusionModel, self).__init__()

        self.temporal_conv_swin = TemporalConv1D(self.swin_feat_dim[-1], 256, kernel_size=3, stride=1, 
                                                 padding =1,dp=0) 

        self.temporal_conv_wav2vec = TemporalConv1D( 13, 256, kernel_size=3, stride=1, 
                                                 padding =1,dp=0)
        self.cross_attention = CrossAttention(embed_dim=256, num_heads=8,dp=0)
        self.mhsa = MHSA(embed_dim =256  ,num_heads = 8 , dp = 0 )

        self.globalpool = nn.Sequential(
            nn.AdaptiveAvgPool1d(1)  # Global temporal pooling
        )

        self.classifier = nn.Sequential(
            nn.Linear(256,128),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(128, 1)
        )
        
        # Apply custom weight initialization
        self.apply(self.kaiming_initialize)
    
    def kaiming_initialize(self,layer):
        """Apply Kaiming initialization for all relevant layers, including MultiHeadAttention."""
        if isinstance(layer, nn.Conv1d):
            nn.init.kaiming_normal_(layer.weight, mode='fan_out', nonlinearity='relu')
            if layer.bias is not None:
                nn.init.constant_(layer.bias, 0)
        elif isinstance(layer, nn.Linear):
            nn.init.kaiming_normal_(layer.weight, mode='fan_in', nonlinearity='relu')
            if layer.bias is not None:
                nn.init.constant_(layer.bias, 0)
        elif isinstance(layer, nn.MultiheadAttention):
            # Initialize in_proj_weight and in_proj_bias
            nn.init.kaiming_normal_(layer.in_proj_weight, mode='fan_in', nonlinearity='relu')
            if layer.in_proj_bias is not None:
                nn.init.constant_(layer.in_proj_bias, 0)
            # Initialize out_proj weight and bias
            nn.init.kaiming_normal_(layer.out_proj.weight, mode='fan_in', nonlinearity='relu')
            if layer.out_proj.bias is not None:
                nn.init.constant_(layer.out_proj.bias, 0)

    

    def forward(self, swin_features,wav2vec_features ):

        # swin_features (B,50,1024)
        swin_features = swin_features.permute(0,2,1) # (B,1024,50)
        swin_features = self.temporal_conv_swin ( swin_features).permute(0,2,1) # (B,256,50)
        swin_features = self.mhsa( swin_features ) # (B,50,256)
        # print( "Swin processing",swin_features.shape) 

        # wav2vec_features (B,2811,13)
        wav2vec_features = wav2vec_features[:,0:2000,:]
        wav2vec_features = wav2vec_features.view(-1,50,40,13)
        wav2vec_features = wav2vec_features.mean(dim=2) # (B,50,13)
        wav2vec_features = wav2vec_features.permute(0,2,1) # (B,13,50)
        wav2vec_features = self.temporal_conv_wav2vec(wav2vec_features).permute(0,2,1) # (B,50,256)
        # print('wav2vec processing', wav2vec_features.shape)

        # cross attention   
        output = self.cross_attention(swin_features, wav2vec_features, wav2vec_features) # (B,50,256)
        # print( 'cross-attention processing',output.shape)

        # mhsa
        output = self.mhsa(output) # (B,50,256)
        # print( 'mhsa processing',output.shape)

        # global pooling    
        output = self.globalpool(output.permute(0,2,1)).squeeze(-1) # (B,256)
        # print( 'global pooling processing',output.shape)

        # classification
        output = self.classifier(output) # (B,1)

        return output.squeeze(-1)

# %%
def load_data(swin_file_path,labels_file_path):
     
    swin_features = np.load(swin_file_path)
    labels = np.load(labels_file_path)
    
    return swin_features,labels

# %%
def dataloaders (swin_train,swin_val,swin_test,
                 wav2vec_train,wav2vec_val,wav2vec_test,
                 labels_train,labels_val,labels_test,
                 batch_size):
    # Convert numpy arrays to PyTorch tensors
    swin_train_tensor = torch.tensor(swin_train, dtype=torch.float32)
    swin_val_tensor = torch.tensor(swin_val, dtype=torch.float32)
    swin_test_tensor = torch.tensor(swin_test, dtype=torch.float32)

    wav2vec_train_tensor = torch.tensor(wav2vec_train, dtype=torch.float32)
    wav2vec_val_tensor = torch.tensor(wav2vec_val, dtype=torch.float32)
    wav2vec_test_tensor = torch.tensor(wav2vec_test, dtype=torch.float32)

    labels_train_tensor = torch.tensor(labels_train, dtype=torch.long)
    labels_val_tensor = torch.tensor(labels_val, dtype=torch.long)
    labels_test_tensor = torch.tensor(labels_test, dtype=torch.long)

    # Create TensorDatasets
    train_dataset = TensorDataset(swin_train_tensor,wav2vec_train_tensor, labels_train_tensor)
    val_dataset = TensorDataset(swin_val_tensor,wav2vec_val_tensor, labels_val_tensor)
    test_dataset = TensorDataset(swin_test_tensor,wav2vec_test_tensor, labels_test_tensor)

    # Optional: Create DataLoader
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

    return train_loader,val_loader,test_loader

# %%
# def plot_graph(train_accuracies, train_losses, val_accuracies, val_losses, num_epochs):
#     # import matplotlib.pyplot as plt

#     epochs = range(1, num_epochs + 1)

#     # Set figure size and reduce resolution via dpi
#     fig, ax1 = plt.subplots(figsize=(7, 5), dpi=72)

#     # Plot accuracy curves on the left y-axis
#     ax1.plot(epochs, train_accuracies, label='Training Accuracy', color='blue', marker='o', linestyle='-')
#     ax1.plot(epochs, val_accuracies, label='Validation Accuracy', color='green', marker='s', linestyle='--')
#     ax1.set_xlabel('Epochs')
#     ax1.set_ylabel('Accuracy (%)', color='black')
#     ax1.tick_params(axis='y', labelcolor='black')

#     # Create a twin axis for the loss curves
#     ax2 = ax1.twinx()
#     ax2.plot(epochs, train_losses, label='Training Loss', color='red', marker='o', linestyle='-')
#     ax2.plot(epochs, val_losses, label='Validation Loss', color='orange', marker='s', linestyle='--')
#     ax2.set_ylabel('Loss', color='black')
#     ax2.tick_params(axis='y', labelcolor='black')

#     # Combine legends from both axes
#     lines_1, labels_1 = ax1.get_legend_handles_labels()
#     lines_2, labels_2 = ax2.get_legend_handles_labels()
#     ax1.legend(lines_1 + lines_2, labels_1 + labels_2, loc='upper center', ncol=2)

#     plt.title('Training vs Validation Metrics')
#     plt.tight_layout()
#     plt.show()

import matplotlib.pyplot as plt

def plot_graph(train_accuracies, train_losses, val_accuracies, val_losses, num_epochs):
    epochs = range(1, num_epochs + 1)

    # Set figure size and high resolution for publication-quality output
    fig, ax1 = plt.subplots(figsize=(7, 5), dpi=300)

    # Plot accuracy curves on the left y-axis using standard 'tab:' colors without markers
    ax1.plot(epochs, train_accuracies, label='Training Accuracy', color='tab:blue', linestyle='-')
    ax1.plot(epochs, val_accuracies, label='Validation Accuracy', color='tab:green', linestyle='--')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Accuracy (%)')
    ax1.tick_params(axis='y')

    # Create a twin axis for the loss curves using standard 'tab:' colors
    ax2 = ax1.twinx()
    ax2.plot(epochs, train_losses, label='Training Loss', color='tab:red', linestyle='-')
    ax2.plot(epochs, val_losses, label='Validation Loss', color='tab:orange', linestyle='--')
    ax2.set_ylabel('Loss')
    ax2.tick_params(axis='y')

    # Combine legends from both axes into one, placed centrally at the top
    lines1, labels1 = ax1.get_legend_handles_labels()
    lines2, labels2 = ax2.get_legend_handles_labels()
    ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper center', ncol=2)

    # Optional: Add a light grid for easier interpretation of the data
    ax1.grid(True, linestyle=':', linewidth=0.5)

    plt.title('Training vs Validation Metrics')
    plt.tight_layout()
    plt.show()

# %%
def train(model,train_loader,val_loader,device,num_epochs,lr,batch_size,weight_decay):

    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    criterion = nn.BCEWithLogitsLoss()

    train_losses = []
    train_accuracies = []
    val_losses = []  
    val_accuracies = []

    for epoch in range(num_epochs) :
        model.train()

        running_loss = 0
        correct_train = 0
        total_train = 0

        for swin_features,wav2vec_features,labels in train_loader:
            swin_features = swin_features.to(device)
            wav2vec_features = wav2vec_features.to(device)
            labels = labels.to(device)

            # Zero your gradients for every batch!
            optimizer.zero_grad()
            
            # Make predictions for this batch      
            outputs = model(swin_features,wav2vec_features)
            
            # Compute the loss and its gradients
            loss = criterion(outputs, labels.float())
            loss.backward()

            # Adjust learning weights        
            optimizer.step()

            running_loss += loss.data.item()
            predicted = (torch.sigmoid(outputs) > 0.5).float()  # Apply threshold for binary classification
            total_train += labels.size(0)
            correct_train += (predicted.view(-1) == labels.float()).sum().item()  # Ensure same shape

        
        epoch_loss = running_loss / len(train_loader)
        epoch_acc = 100 * correct_train / total_train
        print(f'epoch [{epoch }/{num_epochs}], train_loss: {epoch_loss:.4f}, train_accuracy: {epoch_acc:.2f}%')
    
        train_losses.append(epoch_loss)
        train_accuracies.append(epoch_acc)

        model.eval()

        correct_val = 0
        total_val = 0
        running_val_loss = 0.0

        with torch.no_grad():
            for swin_features,wav2vec_features, labels in val_loader:
                
                swin_features = swin_features.to(device)
                wav2vec_features = wav2vec_features.to(device)
                labels = labels.to(device)
                
                outputs = model(swin_features,wav2vec_features)
                loss = criterion(outputs, labels.float())

                running_val_loss += loss.data.item()

                predicted = (torch.sigmoid(outputs) > 0.5).float() 
                total_val += labels.size(0)
                correct_val += (predicted.view(-1) == labels.float()).sum().item()  
                
        val_acc = 100 * correct_val / total_val
        val_loss = running_val_loss / len(val_loader)

        val_accuracies.append(val_acc)
        val_losses.append(val_loss)
        print(f'validation_loss: {val_loss:.4f}, validation_accuracy: {val_acc:.2f}%')

        torch.cuda.empty_cache()    


    plot_graph( train_accuracies ,train_losses, val_accuracies ,val_losses, num_epochs )

# %%
# Hyperparameters
lr = 0.001
batch_size = 256
num_epochs = 18
seed = 42
weight_decay = 0.001

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Seeting the seed
set_seed( seed )

# Folders
swin_file = r"swin_features.npy"
wav2vec_file = r"audio_features.npy"
labels_file = r"labels.npy"

# Loading the data 
swin_data,labels = load_data(swin_file,labels_file)
wav2vec_data,labels = load_data(wav2vec_file,labels_file)
print( "SwinData loaded",swin_data.shape)
print( "Wav2vecData loaded",wav2vec_data.shape)
print( "labels loaded",labels.shape)

# Data splitting
swin_train, swin_temp, labels_train, labels_temp = train_test_split(swin_data, labels, test_size=0.2, stratify=labels, random_state=42)
swin_val, swin_test, labels_val, labels_test = train_test_split(swin_temp, labels_temp, test_size=0.5, stratify=labels_temp, random_state=42)
print("Swin_train shape ",swin_train.shape)

wav2vec_train, wav2vec_temp, labels_train, labels_temp = train_test_split(wav2vec_data, labels, test_size=0.2, stratify=labels, random_state=42)
wav2vec_val, wav2vec_test, labels_val, labels_test = train_test_split(wav2vec_temp, labels_temp, test_size=0.5, stratify=labels_temp, random_state=42)

# Dataloaders
train_loader,val_loader,test_loader = dataloaders(swin_train,swin_val,swin_test,
                                                  wav2vec_train,wav2vec_val,wav2vec_test,
                                                  labels_train,labels_val,labels_test
                                                  ,batch_size)

# Setting up the model
model = FusionModel().to(device)

# Training the mdoel
train(model,train_loader,val_loader,device,num_epochs,lr,batch_size,weight_decay)
# Out:
# SwinData loaded (7602, 50, 1024)
# Wav2vecData loaded (7602, 2811, 13)
# labels loaded (7602,)
# Swin_train shape  (6081, 50, 1024)
# epoch [0/18], train_loss: 2.1827, train_accuracy: 54.97%
# validation_loss: 0.7874, validation_accuracy: 53.68%
# epoch [1/18], train_loss: 0.7176, train_accuracy: 60.43%
# validation_loss: 0.6018, validation_accuracy: 66.58%
# epoch [2/18], train_loss: 0.5902, train_accuracy: 67.28%
# validation_loss: 0.5821, validation_accuracy: 68.29%
# epoch [3/18], train_loss: 0.5466, train_accuracy: 70.70%
# validation_loss: 0.5376, validation_accuracy: 71.45%
# epoch [4/18], train_loss: 0.4972, train_accuracy: 74.44%
# validation_loss: 0.5163, validation_accuracy: 73.82%
# epoch [5/18], train_loss: 0.4559, train_accuracy: 77.11%
# validation_loss: 0.4823, validation_accuracy: 76.32%
# epoch [6/18], train_loss: 0.4095, train_accuracy: 80.81%
# validation_loss: 0.4537, validation_accuracy: 77.11%
# epoch [7/18], train_loss: 0.3731, train_accuracy: 83.05%
# validation_loss: 0.4168, validation_accuracy: 79.74%
# epoch [8/18], train_loss: 0.3462, train_accuracy: 84.69%
# validation_loss: 0.4157, validation_accuracy: 80.66%
# epoch [9/18], train_loss: 0.2955, train_accuracy: 87.34%
# validation_loss: 0.4019, validation_accuracy: 83.16%
# epoch [10/18], train_loss: 0.2953, train_accuracy: 87.65%
# validation_loss: 0.4272, validation_accuracy: 82.11%
# epoch [11/18], train_loss: 0.2558, train_accuracy: 89.64%
# validation_loss: 0.3436, validation_accuracy: 84.87%
# epoch [12/18], train_loss: 0.2380, train_accuracy: 89.94%
# validation_loss: 0.3171, validation_accuracy: 85.92%
# epoch [13/18], train_loss: 0.2238, train_accuracy: 90.74%
# validation_loss: 0.3980, validation_accuracy: 82.50%
# epoch [14/18], train_loss: 0.2037, train_accuracy: 91.98%
# validation_loss: 0.2800, validation_accuracy: 89.47%
# epoch [15/18], train_loss: 0.1877, train_accuracy: 93.01%
# validation_loss: 0.3457, validation_accuracy: 86.84%
# epoch [16/18], train_loss: 0.1938, train_accuracy: 92.78%
# validation_loss: 0.3170, validation_accuracy: 89.74%
# epoch [17/18], train_loss: 0.1622, train_accuracy: 93.90%
# validation_loss: 0.2743, validation_accuracy: 89.87%

# %%
# Testing the model 

model.eval()

correct_test = 0
total_test = 0

with torch.no_grad():
    for swin_features,wav2vec_features, labels in test_loader:
        
        swin_features = swin_features.to(device)
        wav2vec_features = wav2vec_features.to(device)
        labels = labels.to(device)
        
        outputs = model(swin_features,wav2vec_features) 

        predicted = (torch.sigmoid(outputs) > 0.5).float() 
        total_test += labels.size(0)
        correct_test += (predicted.view(-1) == labels.float()).sum().item()  
        
test_acc = 100 * correct_test / total_test
print( test_acc )
# Out:
# 88.5676741130092
